# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ## ORDER

# %%
orders_df = pd.read_excel('order.xlsx', index_col=0)
orders_df['deadline'] = pd.to_datetime( orders_df['deadline'])

# %%
orders_df.head()
# Out:
#                    product_id  amount   deadline
# _id
# 0    5c94953dc9e77c0001d5e130     520 2019-04-01
# 1    5c94953dc9e77c0001d5e12b    1000 2019-04-03
# 2    5c94953dc9e77c0001d5e131     360 2019-04-10
# 3    5c94953dc9e77c0001d5e141      90 2019-03-25
# 4    5c94953dc9e77c0001d5e139     860 2019-04-16

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124949 entries, 0 to 124948
# Data columns (total 3 columns):
# product_id    124949 non-null object
# amount        124949 non-null int64
# deadline      124949 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 3.8+ MB

# %%
orders_df.describe()
# Out:
#               amount
# count  124949.000000
# mean      524.987155
# std       273.446274
# min        50.000000
# 25%       290.000000
# 50%       520.000000
# 75%       760.000000
# max      1000.000000

# %%
orders_df.describe(include=['object','datetime64[ns]'])
# Out:
#                       product_id             deadline
# count                     124949               124949
# unique                        37                   30
# top     5c94953dc9e77c0001d5e125  2019-04-20 00:00:00
# freq                        3377                 4179
# first                        NaN  2019-03-22 00:00:00
# last                         NaN  2019-04-20 00:00:00

# %%
orders_df.groupby('deadline').size()
# Out:
# deadline
# 2019-03-22    4169
# 2019-03-23    4174
# 2019-03-24    4164
# 2019-03-25    4171
# 2019-03-26    4173
# 2019-03-27    4170
# 2019-03-28    4144
# 2019-03-29    4164
# 2019-03-30    4160
# 2019-03-31    4164
# 2019-04-01    4174
# 2019-04-02    4162
# 2019-04-03    4174
# 2019-04-04    4156
# 2019-04-05    4156
# 2019-04-06    4157
# 2019-04-07    4161
# 2019-04-08    4161
# 2019-04-09    4160
# 2019-04-10    4155
# 2019-04-11    4167
# 2019-04-12    4159
# 2019-04-13    4173
# 2019-04-14    4168
# 2019-04-15    4173
# 2019-04-16    4161
# 2019-04-17    4155
# 2019-04-18    4171
# 2019-04-19    4174
# 2019-04-20    4179
# dtype: int64

# %% [markdown]
# ## EQUIPMENT

# %%
equipment_df = pd.read_excel('equipment_2.xlsx', index_col=0)

# %%
equipment_df.head()
# Out:
#                                                                                   class  \
# id
# 7596f724-c038-11e6-80c1-e1497160343b                                   Масс-спектрометр
# 0ea79b45-aa16-11e5-80d6-00505692e771  Бокс химической защиты с двойной системой филь...
# e2de4578-93a6-11e7-80da-00155df02900                                Хроматограф газовый
# cd806b45-26fd-11e5-80c0-00505692e771                                               Весы
# 8392404a-f2a4-11e6-80d2-00155df02900                             Хроматограф жидкостный
#
#                                       available_hours  speed_per_hour
# id
# 7596f724-c038-11e6-80c1-e1497160343b              NaN              60
# 0ea79b45-aa16-11e5-80d6-00505692e771              NaN             100
# e2de4578-93a6-11e7-80da-00155df02900              NaN              55
# cd806b45-26fd-11e5-80c0-00505692e771              NaN              95
# 8392404a-f2a4-11e6-80d2-00155df02900              NaN              70

# %%
equipment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541 entries, 7596f724-c038-11e6-80c1-e1497160343b to 6ca97f03-2d89-11e6-80e8-00505692e771
# Data columns (total 3 columns):
# class              541 non-null object
# available_hours    0 non-null float64
# speed_per_hour     541 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 16.9+ KB

# %%
equipment_df.describe(include=['object'])
# Out:
#                          class
# count                      541
# unique                     116
# top     Хроматограф жидкостный
# freq                       104

# %%
eqpt_classes = equipment_df.groupby('class')['speed_per_hour'].sum()
eqpt_classes
# Out:
# class
# CO2-инкубатор                                               95
# pH-метр                                                    650
# Автоклав                                                   605
# Автоматизированная система для клеточного клонирования      60
# Автоматизированная система для переноса колоний            115
# Автоматизированная система подачи плашек                    90
# Автостейнер                                                 85
# Автосэмплер                                                100
# Амплификатор                                               670
# Анализатор биохимический                                    80
# Анализатор динамического светорассеяния                     85
# Анализатор жизнеспособности клеток                          65
# Анализатор иммуноферментный                                150
# Анализатор общего углерода                                  60
# Анализатор светорассеяния                                   95
# Анализатор гематологический                                 95
# Аппарат для определения растворимости таблеток              70
# Биореактор                                                 275
# Биоробот                                                    65
# Блистерная машина                                           50
# Блок питания                                               145
# Бокс химической защиты с двойной системой фильтрации       100
# Вакуумный концентратор                                     230
# Вентиляционный блок                                         90
# Весы                                                      1100
# Вортекс                                                    215
# Высокоскоростной смеситель-гранулятор                       65
# Вытяжной шкаф                                              105
# Генератор чистого азота                                    245
# Генератор чистого водорода                                 215
#                                                           ...
# Система капиллярного электрофореза                        1800
# Система очистки                                             65
# Система очистки воды                                       385
# Система управления биореактором                            265
# Спектрофотометр                                            845
# Станция для фиксации тканей                                155
# Станция растворения                                        470
# Струйная мельница                                           55
# Сухожаровой шкаф                                           325
# Сушильный шкаф                                             220
# Счетчик клеток                                              60
# Таблетпресс                                                 60
# Термостат твердотельный                                    120
# Термостат рециркуляционный                                 150
# Термошейкер                                                325
# Тестер распадаемости                                        80
# Титратор                                                   490
# Трансформатор                                               95
# УФ лампа                                                   135
# Установка тангенциальной фильтрации                        165
# Френчпрес                                                  115
# Холодильник                                               1205
# Хромато-масс-спектрометр                                    65
# Хроматограф газовый                                        670
# Хроматограф жидкостный                                    7735
# Центрифуга                                                 625
# Шейкер                                                     140
# Шейкер-CO2-инкубатор                                       990
# Шейкер-инкубатор                                            55
# Электропоратор                                             155
# Name: speed_per_hour, Length: 116, dtype: int64

# %%
eqpt_nouse = pd.Series(eqpt_classes.index.values).apply(lambda a: a.find('НЕ ИСПОЛЬЗОВАТЬ') != -1)
eqpt_nouse.index = eqpt_classes.index
eqpt_classes[eqpt_nouse==True]
# Out:
# Series([], Name: speed_per_hour, dtype: int64)

# %%
no_use_equipment = list(eqpt_classes[eqpt_nouse==True].index)
no_use_equipment
# Out:
# []

# %% [markdown]
# ## PRODUCT

# %%
product_df = pd.read_excel('product_2.xlsx', index_col=0)

# %%
product_df.head()
# Out:
#                                                             equipment_class
# _id
# 5c94953dc9e77c0001d5e130  ['Хроматограф жидкостный', 'Насос', 'Принтер д...
# 5c94953dc9e77c0001d5e12b  ['Вытяжной шкаф', 'pH-метр', 'Система капилляр...
# 5c94953dc9e77c0001d5e131  ['Манипулятор переносящий', 'Криохранилище', '...
# 5c94953dc9e77c0001d5e141     ['Рециркулятор', 'Изолятор', 'Счетчик клеток']
# 5c94953dc9e77c0001d5e139  ['Лабораторное оборудование', 'Синтезатор олиг...

# %%
production_classes = []
for s in product_df['equipment_class']:
    processed_s = s.replace("'",'"').replace('\\xa0',' ')
    for e in json.loads(processed_s):
        if ( e not in production_classes ):
            production_classes.append(e)
production_classes.sort()
print(len(production_classes))

for nu in no_use_equipment:
    try:
        production_classes.remove(nu)
    except ValueError:
        pass
    
production_classes
# Out:
# 98
# ['pH-метр',
#  'Автоклав',
#  'Автоматизированная система для клеточного клонирования',
#  'Автоматизированная система для переноса колоний',
#  'Автоматизированная система подачи плашек',
#  'Автостейнер',
#  'Амплификатор',
#  'Анализатор биохимический',
#  'Анализатор гематологический',
#  'Анализатор динамического светорассеяния',
#  'Анализатор жизнеспособности клеток',
#  'Анализатор общего углерода',
#  'Анализатор светорассеяния',
#  'Аппарат для определения растворимости таблеток',
#  'Биоробот',
#  'Блистерная машина',
#  'Блок питания',
#  'Бокс химической защиты с двойной системой фильтрации',
#  'Вакуумный концентратор',
#  'Весы',
#  'Вортекс',
#  'Высокоскоростной смеситель-гранулятор',
#  'Вытяжной шкаф',
#  'Генератор чистого азота',
#  'Генератор чистого водорода',
#  'Генетический анализатор',
#  'Детектор',
#  'Дозатор',
#  'ИК-спектрометр',
#  'Изолятор',
#  'Инженерное оборудование',
#  'Инкубатор',
#  'Источник бесперебойного питания',
#  'Калориметр',
#  'Камера для изоэлектрофокусирования',
#  'Камера для иммуноблоттинга',
#  'Камера для электропереноса',
#  'Коатер',
#  'Компьютерные системы',
#  'Кондуктометр',
#  'Коническая мельница',
#  'Криохранилище',
#  'Лабораторная мебель',
#  'Лабораторная мельница для измельчения образцов',
#  'Лабораторное оборудование',
#  'Лабораторный 3D смеситель',
#  'Ламинар',
#  'Манипулятор переносящий',
#  'Масс-спектрометр',
#  'Микробиологический пробоотборник воздуха',
#  'Микротом',
#  'Морозильник',
#  'Муфельная печь',
#  'Насос',
#  'Облучатель бактерицидный',
#  'Осмометр',
#  'ПЦР-бокс',
#  'Передаточное окно',
#  'Пресс ручной',
#  'Прибор для определения точки плавления',
#  'Принтер для этикеток',
#  'Производственное оборудование',
#  'Проточный цитофлуориметр',
#  'Процессор магнитных частиц',
#  'Рабочий стол роботизированной станции',
#  'Реактор',
#  'Регистратор невидимых частиц',
#  'Рециркулятор',
#  'Ротационный испаритель',
#  'Секвенатор',
#  'Синтезатор олигонуклеотидов',
#  'Система визуализации',
#  'Система капиллярного электрофореза',
#  'Система очистки',
#  'Система очистки воды',
#  'Система управления биореактором',
#  'Спектрофотометр',
#  'Станция растворения',
#  'Струйная мельница',
#  'Сухожаровой шкаф',
#  'Сушильный шкаф',
#  'Счетчик клеток',
#  'Таблетпресс',
#  'Термостат рециркуляционный',
#  'Термостат твердотельный',
#  'Термошейкер',
#  'Титратор',
#  'Трансформатор',
#  'Установка тангенциальной фильтрации',
#  'Френчпрес',
#  'Холодильник',
#  'Хромато-масс-спектрометр',
#  'Хроматограф жидкостный',
#  'Центрифуга',
#  'Шейкер',
#  'Шейкер-CO2-инкубатор',
#  'Шейкер-инкубатор',
#  'Электропоратор']

# %%
product_requirements = {}
for i in product_df.index:
    s = product_df['equipment_class'][i]
    processed_s = s.replace("'",'"').replace('\\xa0',' ')
    L = json.loads(processed_s)
    for nu in no_use_equipment:
        try:
            L.remove(nu)
        except ValueError:
            pass
    product_requirements[i] = L
product_requirements
# Out:
# {'5c94953dc9e77c0001d5e130': ['Хроматограф жидкостный',
#   'Насос',
#   'Принтер для этикеток',
#   'Сухожаровой шкаф',
#   'Автостейнер'],
#  '5c94953dc9e77c0001d5e12b': ['Вытяжной шкаф',
#   'pH-метр',
#   'Система капиллярного электрофореза'],
#  '5c94953dc9e77c0001d5e131': ['Манипулятор переносящий',
#   'Криохранилище',
#   'Высокоскоростной смеситель-гранулятор',
#   'Хромато-масс-спектрометр'],
#  '5c94953dc9e77c0001d5e141': ['Рециркулятор', 'Изолятор', 'Счетчик клеток'],
#  '5c94953dc9e77c0001d5e139': ['Лабораторное оборудование',
#   'Синтезатор олигонуклеотидов',
#   'Производственное оборудование',
#   'Шейкер',
#   'Амплификатор',
#   'Изолятор',
#   'Аппарат для определения растворимости таблеток',
#   'Лабораторный 3D смеситель'],
#  '5c94953dc9e77c0001d5e12d': ['Сушильный шкаф',
#   'Проточный цитофлуориметр',
#   'Установка тангенциальной фильтрации',
#   'Автоклав',
#   'Микротом',
#   'Анализатор общего углерода',
#   'Анализатор биохимический',
#   'Секвенатор',
#   'Камера для электропереноса'],
#  '5c94953dc9e77c0001d5e136': ['Морозильник',
#   'Термостат рециркуляционный',
#   'Анализатор жизнеспособности клеток'],
#  '5c94953dc9e77c0001d5e137': ['Проточный цитофлуориметр',
#   'Принтер для этикеток',
#   'Система визуализации'],
#  '5c94953dc9e77c0001d5e13c': ['Анализатор динамического светорассеяния',
#   'Струйная мельница',
#   'Генетический анализатор',
#   'Блок питания',
#   'Сухожаровой шкаф',
#   'Манипулятор переносящий',
#   'Система капиллярного электрофореза',
#   'Проточный цитофлуориметр'],
#  '5c94953dc9e77c0001d5e13f': ['Сухожаровой шкаф'],
#  '5c94953dc9e77c0001d5e13d': ['pH-метр',
#   'Система визуализации',
#   'Дозатор',
#   'ИК-спектрометр',
#   'Титратор',
#   'Автоматизированная система для переноса колоний'],
#  '5c94953dc9e77c0001d5e121': ['Коническая мельница',
#   'Регистратор невидимых частиц'],
#  '5c94953dc9e77c0001d5e12f': ['Криохранилище'],
#  '5c94953dc9e77c0001d5e128': ['Анализатор светорассеяния',
#   'Коническая мельница'],
#  '5c94953dc9e77c0001d5e134': ['Осмометр', 'Станция растворения'],
#  '5c94953dc9e77c0001d5e133': ['Автостейнер',
#   'Кондуктометр',
#   'Френчпрес',
#   'Биоробот',
#   'Генератор чистого азота',
#   'Автоклав',
#   'Изолятор',
#   'Хромато-масс-спектрометр',
#   'Анализатор светорассеяния'],
#  '5c94953dc9e77c0001d5e138': ['Центрифуга',
#   'Камера для изоэлектрофокусирования',
#   'Ротационный испаритель',
#   'Масс-спектрометр',
#   'Процессор магнитных частиц',
#   'Анализатор гематологический'],
#  '5c94953dc9e77c0001d5e13b': ['Система капиллярного электрофореза',
#   'Вакуумный концентратор'],
#  '5c94953dc9e77c0001d5e129': ['Электропоратор',
#   'Термостат твердотельный',
#   'Шейкер-инкубатор',
#   'Система очистки',
#   'Спектрофотометр',
#   'Весы',
#   'Автоматизированная система для переноса колоний',
#   'Камера для иммуноблоттинга',
#   'Шейкер-CO2-инкубатор'],
#  '5c94953dc9e77c0001d5e140': ['Высокоскоростной смеситель-гранулятор'],
#  '5c94953dc9e77c0001d5e132': ['Рециркулятор',
#   'Амплификатор',
#   'Передаточное окно',
#   'ИК-спектрометр',
#   'Высокоскоростной смеситель-гранулятор',
#   'Термошейкер',
#   'Камера для электропереноса'],
#  '5c94953dc9e77c0001d5e125': ['Процессор магнитных частиц',
#   'Лабораторная мебель',
#   'Генератор чистого водорода',
#   'Аппарат для определения растворимости таблеток',
#   'Рабочий стол роботизированной станции',
#   'Инкубатор',
#   'Осмометр',
#   'Лабораторная мельница для измельчения образцов',
#   'Струйная мельница'],
#  '5c94953dc9e77c0001d5e142': ['Вакуумный концентратор',
#   'Титратор',
#   'Насос',
#   'Анализатор биохимический',
#   'Источник бесперебойного питания',
#   'Лабораторная мельница для измельчения образцов',
#   'Трансформатор',
#   'Система очистки',
#   'Таблетпресс'],
#  '5c94953dc9e77c0001d5e144': ['Дозатор',
#   'Система капиллярного электрофореза',
#   'Блистерная машина',
#   'Осмометр',
#   'Центрифуга',
#   'Система очистки',
#   'Таблетпресс'],
#  '5c94953dc9e77c0001d5e122': ['Инженерное оборудование',
#   'Кондуктометр',
#   'Передаточное окно',
#   'Изолятор',
#   'Ротационный испаритель'],
#  '5c94953dc9e77c0001d5e135': ['Термостат твердотельный',
#   'Генетический анализатор',
#   'Сушильный шкаф',
#   'Лабораторная мебель',
#   'Облучатель бактерицидный',
#   'Муфельная печь',
#   'Счетчик клеток',
#   'Генератор чистого водорода'],
#  '5c94953dc9e77c0001d5e12e': ['Камера для изоэлектрофокусирования',
#   'Центрифуга',
#   'Система визуализации',
#   'Вортекс',
#   'Компьютерные системы',
#   'Аппарат для определения растворимости таблеток'],
#  '5c94953dc9e77c0001d5e124': ['Ламинар'],
#  '5c94953dc9e77c0001d5e126': ['Лабораторная мельница для измельчения образцов',
#   'Электропоратор',
#   'Френчпрес',
#   'Бокс химической защиты с двойной системой фильтрации',
#   'Микробиологический пробоотборник воздуха',
#   'Инкубатор',
#   'Регистратор невидимых частиц',
#   'pH-метр',
#   'Прибор для определения точки плавления'],
#  '5c94953dc9e77c0001d5e145': ['Генератор чистого водорода',
#   'Шейкер-CO2-инкубатор',
#   'Криохранилище',
#   'Лабораторный 3D смеситель',
#   'Осмометр',
#   'Камера для иммуноблоттинга',
#   'ПЦР-бокс',
#   'Система управления биореактором'],
#  '5c94953dc9e77c0001d5e12c': ['Вортекс',
#   'Пресс ручной',
#   'Генетический анализатор',
#   'Криохранилище',
#   'Инженерное оборудование',
#   'Детектор',
#   'Таблетпресс',
#   'Калориметр'],
#  '5c94953dc9e77c0001d5e127': ['Амплификатор',
#   'Холодильник',
#   'Шейкер-CO2-инкубатор',
#   'Хроматограф жидкостный',
#   'Источник бесперебойного питания',
#   'pH-метр',
#   'Хромато-масс-спектрометр'],
#  '5c94953dc9e77c0001d5e13a': ['Камера для иммуноблоттинга',
#   'Коническая мельница',
#   'Система управления биореактором'],
#  '5c94953dc9e77c0001d5e143': ['Камера для изоэлектрофокусирования',
#   'Автоматизированная система подачи плашек',
#   'Вортекс',
#   'Коническая мельница',
#   'ПЦР-бокс',
#   'Система очистки воды'],
#  '5c94953dc9e77c0001d5e13e': ['Коатер',
#   'Счетчик клеток',
#   'Блок питания',
#   'Амплификатор',
#   'Лабораторное оборудование',
#   'Автоматизированная система для клеточного клонирования',
#   'Реактор',
#   'Генератор чистого азота',
#   'Манипулятор переносящий'],
#  '5c94953dc9e77c0001d5e123': ['Насос', 'Система управления биореактором'],
#  '5c94953dc9e77c0001d5e12a': ['Холодильник', 'Счетчик клеток']}

# %% [markdown]
# ## EQUIPMENT HISTORY

# %%
eqpt_history_df = pd.read_excel('eq_hist_data_2.xlsx')
eqpt_history_df['day'] = pd.to_datetime(eqpt_history_df['day'], unit='s')

# %%
eqpt_history_df.head()
# Out:
#          day                                    id  work  maintenance  idle  \
# 0 2018-10-02  7596f724-c038-11e6-80c1-e1497160343b   0.0          0.0  24.0
# 1 2018-10-02  0ea79b45-aa16-11e5-80d6-00505692e771   0.0          0.0  24.0
# 2 2018-10-02  e2de4578-93a6-11e7-80da-00155df02900  24.0          0.0   0.0
# 3 2018-10-02  cd806b45-26fd-11e5-80c0-00505692e771  24.0          0.0   0.0
# 4 2018-10-02  8392404a-f2a4-11e6-80d2-00155df02900  24.0          0.0   0.0
#
#                                                class
# 0                                   Масс-спектрометр
# 1  Бокс химической защиты с двойной системой филь...
# 2                                Хроматограф газовый
# 3                                               Весы
# 4                             Хроматограф жидкостный

# %%
eqpt_history_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93052 entries, 0 to 93051
# Data columns (total 6 columns):
# day            93052 non-null datetime64[ns]
# id             93052 non-null object
# work           93052 non-null float64
# maintenance    93052 non-null float64
# idle           93052 non-null float64
# class          93052 non-null object
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 4.3+ MB

# %%
set(eqpt_history_df.groupby('class').size().index) == set(eqpt_classes.index)
# Out:
# True

# %%
set(eqpt_history_df.groupby('id').size().index) == set(equipment_df.index)
# Out:
# True

# %%
eqpt_history_df.describe(include=['datetime64[ns]'])
# Out:
#                         day
# count                 93052
# unique                  172
# top     2019-02-17 00:00:00
# freq                    541
# first   2018-10-02 00:00:00
# last    2019-03-22 00:00:00

# %%
eqpt_history_df.groupby('day').size()
# Out:
# day
# 2018-10-02    541
# 2018-10-03    541
# 2018-10-04    541
# 2018-10-05    541
# 2018-10-06    541
# 2018-10-07    541
# 2018-10-08    541
# 2018-10-09    541
# 2018-10-10    541
# 2018-10-11    541
# 2018-10-12    541
# 2018-10-13    541
# 2018-10-14    541
# 2018-10-15    541
# 2018-10-16    541
# 2018-10-17    541
# 2018-10-18    541
# 2018-10-19    541
# 2018-10-20    541
# 2018-10-21    541
# 2018-10-22    541
# 2018-10-23    541
# 2018-10-24    541
# 2018-10-25    541
# 2018-10-26    541
# 2018-10-27    541
# 2018-10-28    541
# 2018-10-29    541
# 2018-10-30    541
# 2018-10-31    541
#              ...
# 2019-02-21    541
# 2019-02-22    541
# 2019-02-23    541
# 2019-02-24    541
# 2019-02-25    541
# 2019-02-26    541
# 2019-02-27    541
# 2019-02-28    541
# 2019-03-01    541
# 2019-03-02    541
# 2019-03-03    541
# 2019-03-04    541
# 2019-03-05    541
# 2019-03-06    541
# 2019-03-07    541
# 2019-03-08    541
# 2019-03-09    541
# 2019-03-10    541
# 2019-03-11    541
# 2019-03-12    541
# 2019-03-13    541
# 2019-03-14    541
# 2019-03-15    541
# 2019-03-16    541
# 2019-03-17    541
# 2019-03-18    541
# 2019-03-19    541
# 2019-03-20    541
# 2019-03-21    541
# 2019-03-22    541
# Length: 172, dtype: int64

# %%
eqpt_history_df.describe()
# Out:
#                work   maintenance          idle
# count  93052.000000  93052.000000  93052.000000
# mean       7.681588      2.141937     14.176475
# std       10.798441      6.263842     11.699947
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000     24.000000
# 75%       24.000000      0.000000     24.000000
# max       24.000000     24.000000     24.000000

# %% [markdown]
# нормальные

# %%
eqpt_history_df[eqpt_history_df['work']+eqpt_history_df['maintenance']+eqpt_history_df['idle'] > 23.9999].shape[0]
# Out:
# 93052

# %% [markdown]
# все нули

# %%
eqpt_history_df[eqpt_history_df['work']+eqpt_history_df['maintenance']+eqpt_history_df['idle'] == 0].shape[0]
# Out:
# 0

# %% [markdown]
# ни рыба ни мясо

# %%
eqpt_history_df[( ( eqpt_history_df['work']+eqpt_history_df['maintenance']+eqpt_history_df['idle'] < 23.9999 )  &
                  ( eqpt_history_df['work']+eqpt_history_df['maintenance']+eqpt_history_df['idle'] > 0 ) )].shape[0]
# Out:
# 0

# %%
good_eqpt_history_df = \
 eqpt_history_df[eqpt_history_df['work']+eqpt_history_df['maintenance']+eqpt_history_df['idle'] == 24.0]
good_eqpt_history_df.shape
# Out:
# (92334, 6)

# %%
maintenance_analysis = eqpt_history_df.groupby('id').agg({'maintenance':[np.mean, np.std, np.sum]})

maintenance_analysis.head()
# Out:
#                                      maintenance
#                                             mean       std         sum
# id
# 00502eec-38a9-11e8-80e1-00155df02900    0.540084  3.345200   92.894444
# 00a1f311-9778-11e6-80fa-00505692e771    1.729464  5.535876  297.467778
# 011f1ac3-3ac3-11e2-b482-b614f2bbba79    2.418605  5.748054  416.000000
# 0297342a-5e11-11e6-80e8-00505692e771    0.000000  0.000000    0.000000
# 0416effa-c625-11e8-80e9-00155df02900    0.000000  0.000000    0.000000

# %%
maintenance_analysis.sort_values(by=[('maintenance','sum')], ascending=False).head(10)
# Out:
#                                      maintenance
#                                             mean       std          sum
# id
# d79b3902-8f22-11e7-80d8-00155df02900   22.697674  3.642086  3904.000000
# c66eb7c8-3e08-11e6-80e8-00505692e771   22.510270  4.418072  3871.766389
# 6fee9b9f-7a60-11e5-80d0-00505692e771   22.093023  3.418655  3800.000000
# 1966e5e8-c622-11e3-8903-6ee664173b4c   21.942477  6.019070  3774.106111
# 4b002ba0-ea2c-11e3-8150-6ee664173b4c   21.128083  7.153940  3634.030278
# e92ef2ea-cb0e-11e5-80d6-00505692e771   20.837209  3.922824  3584.000000
# 571664f5-a2bb-11de-a428-005056c00008   19.860465  4.009237  3416.000000
# 7c5fdfc8-d4ba-11e5-80d8-00505692e771   19.488372  3.978728  3352.000000
# 5427be5a-8c69-11e6-80f6-00505692e771   18.898316  9.805505  3250.510278
# 2b151b3e-2550-11e1-9589-b614f2bbba79   18.000000  8.657215  3096.000000

# %%
eqpt_history_df['day'][0].weekday()
# Out:
# 1

# %% [markdown]
# ### оборудование, работающее в выходные

# %%
w_days = eqpt_history_df['day'].apply(lambda ts:ts.weekday())
eqpt_history_df[(((w_days==6)|(w_days==5))  &
                 (eqpt_history_df['work']+eqpt_history_df['maintenance']+eqpt_history_df['idle']>0)  )]
# Out:
#              day                                    id  work  maintenance  \
# 2164  2018-10-06  7596f724-c038-11e6-80c1-e1497160343b   0.0          0.0
# 2165  2018-10-06  0ea79b45-aa16-11e5-80d6-00505692e771   0.0          0.0
# 2166  2018-10-06  e2de4578-93a6-11e7-80da-00155df02900  24.0          0.0
# 2167  2018-10-06  cd806b45-26fd-11e5-80c0-00505692e771  24.0          0.0
# 2168  2018-10-06  8392404a-f2a4-11e6-80d2-00155df02900  24.0          0.0
# 2169  2018-10-06  0c568299-8f22-11e7-80d8-00155df02900   0.0          0.0
# 2170  2018-10-06  a2e88142-5677-11e3-a533-b614f2bbba79   0.0          0.0
# 2171  2018-10-06  405db8fb-dc53-11e8-80ee-00155df02900   0.0          0.0
# 2172  2018-10-06  85a58e5b-1a4b-11e5-80be-00505692e771   0.0          0.0
# 2173  2018-10-06  a8cf9c8b-59a7-11df-8654-72d93bfbea9b  24.0          0.0
# 2174  2018-10-06  d79b3924-8f22-11e7-80d8-00155df02900   0.0          0.0
# 2175  2018-10-06  854b9ef4-02fa-11e6-80de-00505692e771   0.0          0.0
# 2176  2018-10-06  b36e7e90-74e5-11e6-80f0-00505692e771   0.0          0.0
# 2177  2018-10-06  5a0e4cb4-8f22-11e7-80d8-00155df02900  24.0          0.0
# 2178  2018-10-06  fe02904a-a9ec-11e8-80e6-00155df02900   0.0          0.0
# 2179  2018-10-06  584249b3-9b65-11e6-80fa-00505692e771   0.0          0.0
# 2180  2018-10-06  e9531f95-bb82-11e6-80be-b5eea29936c1  24.0          0.0
# 2181  2018-10-06  857d70dd-edf9-11e6-80d2-00155df02900   0.0          0.0
# 2182  2018-10-06  ded0262e-e4da-11e4-80be-00505692e771   0.0          0.0
# 2183  2018-10-06  fd242b57-1c66-11e8-80e0-00155df02900   0.0          0.0
# 2184  2018-10-06  1e440e62-8f22-11e7-80d8-00155df02900   0.0          0.0
# 2185  2018-10-06  3bf103b0-bf71-11e1-b482-b614f2bbba79   0.0          0.0
# 2186  2018-10-06  2d6bec1f-574c-11e7-80d6-00155df02900   0.0          0.0
# 2187  2018-10-06  9b476fa6-30ad-11e3-a533-b614f2bbba79   0.0          0.0
# 2188  2018-10-06  ab4ace3b-1b98-11e8-80e0-00155df02900   0.0          0.0
# 2189  2018-10-06  17505193-c5d4-11e6-80c6-00155df02900   0.0          0.0
# 2190  2018-10-06  1ee60ec3-d693-11df-b9ac-3279b6ee2664   0.0          0.0
# 2191  2018-10-06  a4c9c53d-f259-11e5-80dc-00505692e771  24.0          0.0
# 2192  2018-10-06  2a25323c-c62a-11e3-8903-6ee664173b4c   0.0          0.0
# 2193  2018-10-06  a3740fde-d4be-11e5-80d8-00505692e771   0.0          0.0
# ...          ...                                   ...   ...          ...
# 90317 2019-03-17  0e8e0a25-e71d-11e6-80d2-00155df02900   0.0          0.0
# 90318 2019-03-17  d1a2f531-8f22-11e7-80d8-00155df02900  24.0          0.0
# 90319 2019-03-17  b1f3cbcc-66a0-11e0-93e1-3279b6ee2664   0.0          0.0
# 90320 2019-03-17  e92ef2ea-cb0e-11e5-80d6-00505692e771   8.0         16.0
# 90321 2019-03-17  a6b36ded-e401-11e7-80e0-00155df02900   0.0          0.0
# 90322 2019-03-17  0f737b78-d4a0-11e6-80c8-00155df02900   0.0          0.0
# 90323 2019-03-17  3c2ba553-8f22-11e7-80d8-00155df02900   0.0          0.0
# 90324 2019-03-17  87b4e1d2-c902-11e6-80c6-00155df02900   0.0          0.0
# 90325 2019-03-17  d59457b4-c938-11e7-80e0-00155df02900   0.0          0.0
# 90326 2019-03-17  60a9ccfc-8ad0-11e8-80e5-00155df02900   0.0          0.0
# 90327 2019-03-17  33abcba4-2b45-11e7-80d6-00155df02900   0.0         24.0
# 90328 2019-03-17  a933f439-a175-11e5-80d6-00505692e771   0.0          0.0
# 90329 2019-03-17  2aea6661-2940-11e5-80c0-00505692e771   8.0         16.0
# 90330 2019-03-17  3631079c-8f22-11e7-80d8-00155df02900   0.0          0.0
# 90331 2019-03-17  a673db9c-6a8a-11e6-80e8-00505692e771  24.0          0.0
# 90332 2019-03-17  c66eb7c8-3e08-11e6-80e8-00505692e771   0.0         24.0
# 90333 2019-03-17  8006a180-a51e-11e7-80de-00155df02900   0.0          0.0
# 90334 2019-03-17  fef4cbc1-e4d2-11e4-80be-00505692e771  24.0          0.0
# 90335 2019-03-17  a12e8784-485b-11e3-a533-b614f2bbba79   0.0          0.0
# 90336 2019-03-17  602d95a8-2940-11e5-80c0-00505692e771   0.0          0.0
# 90337 2019-03-17  10a7d93e-0029-11e8-80e0-00155df02900   0.0          0.0
# 90338 2019-03-17  1e4d6b98-bfd4-11e7-80e0-00155df02900   0.0          0.0
# 90339 2019-03-17  80f0ba46-fd23-11e7-80e0-00155df02900  24.0          0.0
# 90340 2019-03-17  5ef6e995-7045-11e6-80f0-00505692e771   0.0          0.0
# 90341 2019-03-17  c42cbae0-c8de-11e5-80d6-00505692e771   0.0          0.0
# 90342 2019-03-17  8f1878fe-f802-11e6-80d2-00155df02900   8.0         16.0
# 90343 2019-03-17  9bd7f0a9-8f22-11e7-80d8-00155df02900   0.0          0.0
# 90344 2019-03-17  0e2dc969-de6c-11e8-80ee-00155df02900   0.0          0.0
# 90345 2019-03-17  4e1b765e-8f22-11e7-80d8-00155df02900  24.0          0.0
# 90346 2019-03-17  6ca97f03-2d89-11e6-80e8-00505692e771   0.0          0.0
#
#        idle                                              class
# 2164   24.0                                   Масс-спектрометр
# 2165   24.0  Бокс химической защиты с двойной системой филь...
# 2166    0.0                                Хроматограф газовый
# 2167    0.0                                               Весы
# 2168    0.0                             Хроматограф жидкостный
# 2169   24.0                                  Магнитная мешалка
# 2170   24.0                           Камера для электрофореза
# 2171   24.0                      Производственное оборудование
# 2172   24.0                             Хроматограф жидкостный
# 2173    0.0                                    Спектрофотометр
# 2174   24.0                                            Вортекс
# 2175   24.0                 Система капиллярного электрофореза
# 2176   24.0                             Хроматограф жидкостный
# 2177    0.0                                               Весы
# 2178   24.0                        Синтезатор олигонуклеотидов
# 2179   24.0                           Камера для электрофореза
# 2180    0.0                      Производственное оборудование
# 2181   24.0                             Хроматограф жидкостный
# 2182   24.0                        Синтезатор олигонуклеотидов
# 2183   24.0                                      Трансформатор
# 2184   24.0                           Камера для электрофореза
# 2185   24.0                 Камера для изоэлектрофокусирования
# 2186   24.0               Система для выделения плазмидной ДНК
# 2187   24.0                                           Автоклав
# 2188   24.0                      Производственное оборудование
# 2189   24.0                            Манипулятор переносящий
# 2190   24.0                           Проточный цитофлуориметр
# 2191    0.0                             Хроматограф жидкостный
# 2192   24.0                             Хроматограф жидкостный
# 2193   24.0                           Проточный цитофлуориметр
# ...     ...                                                ...
# 90317  24.0                                               Весы
# 90318   0.0                               Система очистки воды
# 90319  24.0                                         Центрифуга
# 90320   0.0                               Климатическая камера
# 90321  24.0                                        Холодильник
# 90322  24.0                                            pH-метр
# 90323  24.0                                        Термошейкер
# 90324  24.0                        Анализатор гематологический
# 90325  24.0                                      Криохранилище
# 90326  24.0                             Хроматограф жидкостный
# 90327   0.0                             Хроматограф жидкостный
# 90328  24.0                             Вакуумный концентратор
# 90329   0.0                             Хроматограф жидкостный
# 90330  24.0                                        Холодильник
# 90331   0.0                               Шейкер-CO2-инкубатор
# 90332   0.0                           Роботизированная станция
# 90333  24.0                 Система капиллярного электрофореза
# 90334   0.0                           Камера для электрофореза
# 90335  24.0                             Хроматограф жидкостный
# 90336  24.0                             Хроматограф жидкостный
# 90337  24.0                               Принтер для этикеток
# 90338  24.0                                       Амплификатор
# 90339   0.0                             Хроматограф жидкостный
# 90340  24.0                    Источник бесперебойного питания
# 90341  24.0                         Процессор магнитных частиц
# 90342   0.0                             Хроматограф жидкостный
# 90343  24.0                      Производственное оборудование
# 90344  24.0                                           Автоклав
# 90345   0.0                             Хроматограф жидкостный
# 90346  24.0                             Хроматограф жидкостный
#
# [25968 rows x 6 columns]
